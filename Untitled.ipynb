# %%
import pandas as pd

# %%
df = pd.read_csv("who_covid_19_sit_rep_time_series.csv")

# %%
df.head()
# Out:
#   Province/States    Country/Region              WHO region WHO region label  \
# 0       Confirmed          Globally                     NaN              NaN
# 1          Deaths          Globally                     NaN              NaN
# 2       Confirmed             China  Western Pacific Region              NaN
# 3       Confirmed  Outside of China                     NaN              NaN
# 4          Deaths             China  Western Pacific Region              NaN
#
#    1/21/20  1/22/20  1/23/20  1/24/20  1/25/20  1/26/20  ...  8/7/20  8/8/20  \
# 0    282.0    314.0    581.0    846.0   1320.0   2014.0  ...     NaN     NaN
# 1      NaN      NaN      NaN      NaN      NaN      NaN  ...     NaN     NaN
# 2    278.0    309.0    571.0    830.0   1297.0   1985.0  ...     NaN     NaN
# 3      4.0      5.0     10.0     16.0     23.0     29.0  ...     NaN     NaN
# 4      NaN      NaN      NaN      NaN      NaN      NaN  ...     NaN     NaN
#
# ...

# %%
pd.DataFrame(df[df["Province/States"] == "Hong Kong"]).to_csv("export.csv")

# %%
df = pd.read_csv("enhanced_sur_covid_19_eng.csv")

# %%
df.head()
# Out:
#    Case no. Report date Date of onset Gender   Age  Name of hospital admitted  \
# 0         1  23/01/2020    21/01/2020      M  39.0                        NaN
# 1         2  23/01/2020    18/01/2020      M  56.0                        NaN
# 2         3  24/01/2020    20/01/2020      F  62.0                        NaN
# 3         4  24/01/2020    23/01/2020      F  62.0                        NaN
# 4         5  24/01/2020    23/01/2020      M  63.0                        NaN
#
#   Hospitalised/Discharged/Deceased HK/Non-HK resident Case classification*  \
# 0                       Discharged    Non-HK resident        Imported case
# 1                       Discharged        HK resident        Imported case
# 2                       Discharged    Non-HK resident        Imported case
# 3                       Discharged    Non-HK resident        Imported case
# 4                       Discharged    Non-HK resident        Imported case
#
#   Confirmed/probable
# 0          Confirmed
# ...

# %%
df["Report date"].unique()
# Out:
# array(['23/01/2020', '24/01/2020', '26/01/2020', '29/01/2020',
#        '30/01/2020', '31/01/2020', '01/02/2020', '02/02/2020',
#        '04/02/2020', '05/02/2020', '06/02/2020', '07/02/2020',
#        '09/02/2020', '10/02/2020', '11/02/2020', '12/02/2020',
#        '13/02/2020', '14/02/2020', '16/02/2020', '17/02/2020',
#        '18/02/2020', '19/02/2020', '20/02/2020', '22/02/2020',
#        '23/02/2020', '24/02/2020', '25/02/2020', '26/02/2020',
#        '27/02/2020', '28/02/2020', '29/02/2020', '01/03/2020',
#        '02/03/2020', '04/03/2020', '06/03/2020', '07/03/2020',
#        '08/03/2020', '09/03/2020', '10/03/2020', '11/03/2020',
#        '12/03/2020', '13/03/2020', '14/03/2020', '15/03/2020',
#        '16/03/2020', '17/03/2020', '18/03/2020', '19/03/2020',
#        '20/03/2020', '21/03/2020', '22/03/2020', '23/03/2020',
#        '24/03/2020', '25/03/2020', '26/03/2020', '27/03/2020',
#        '28/03/2020', '29/03/2020', '30/03/2020', '31/03/2020',
# ...

# %%
df1 = pd.DataFrame(df["Date of onset"].value_counts(sort=False))

# %%
df1.head()
# Out:
#             Report date
# 23/01/2020            2
# 24/01/2020            3
# 26/01/2020            3
# 29/01/2020            2
# 30/01/2020            2
# ...                 ...
# 25/09/2021            9
# 26/09/2021            8
# 27/09/2021            3
# 28/09/2021           13
# 29/09/2021            5
#
# [562 rows x 1 columns]

# %%
df1['date'] = df1.index

# %%
df1['date'] = pd.to_datetime(df1['date'],errors='coerce')

# %%
df1 = df1.dropna()

# %%
import numpy as np

# %%
df1 = df1.reset_index(drop=True)

# %%
df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 479 entries, 0 to 478
# Data columns (total 2 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Date of onset  479 non-null    int64
#  1   date           479 non-null    datetime64[ns]
# dtypes: datetime64[ns](1), int64(1)
# memory usage: 7.6 KB

# %%
df1.to_csv("reported_date_with_count.csv", index=False)

# %%
df1
# Out:
#      Report date       date
# 0              2 2020-01-23
# 1              3 2020-01-24
# 2              3 2020-01-26
# 3              2 2020-01-29
# 4              2 2020-01-30
# ..           ...        ...
# 557            9 2021-09-25
# 558            8 2021-09-26
# 559            3 2021-09-27
# 560           13 2021-09-28
# 561            5 2021-09-29
#
# [562 rows x 2 columns]
